# %%
import random
from PIL import Image, ImageDraw, ImageFont
import numpy as np
import string
import pyphen
import os

# %%
def warp_image(img, gridsize=(26, 26), deviation=1.7):
    """
    Применяет искажение к изображению с использованием случайной сетки.
    """
    (w, h) = img.size

    num_x = w // gridsize[0] + 1
    num_y = h // gridsize[1] + 1

    # Генерация случайной матрицы искажения
    mat = np.random.normal(scale=deviation, size=(num_y + 1, num_x + 1, 2))

    mesh = []
    for x in range(num_x):
        for y in range(num_y):
            target = (x * gridsize[0], y * gridsize[1],
                      (x + 1) * gridsize[0], (y + 1) * gridsize[1])

            nw_y = y * gridsize[1] + mat[y, x, 0]
            nw_x = x * gridsize[0] + mat[y, x, 1]

            sw_y = (y + 1) * gridsize[1] + mat[y + 1, x, 0]
            sw_x = x * gridsize[0] + mat[y + 1, x, 1]

            se_y = (y + 1) * gridsize[1] + mat[y + 1, x + 1, 0]
            se_x = (x + 1) * gridsize[0] + mat[y + 1, x + 1, 1]

            ne_y = y * gridsize[1] + mat[y, x + 1, 0]
            ne_x = (x + 1) * gridsize[0] + mat[y, x + 1, 1]

            source = (nw_x, nw_y, sw_x, sw_y, se_x, se_y, ne_x, ne_y)

            mesh.append((target, source))

    # Применение искажения
    img_transformed = img.transform(
        img.size,
        method=Image.MESH,
        data=mesh,
        fillcolor=255)

    return img_transformed

# %%
# Функция для переноса строк
def wrap_text(text, font, max_width,lines_per_page):
    dic = pyphen.Pyphen(lang='ru')
    lines = []
    output=[]
    text = [i.split() for i in text.split('\n')]
    for words in text:
        while words:
            words[0]=words[0].strip()
            space=random.randint(0,1)*' '
            line = ''+space
            while words and font.getlength(line + words[0] + ' ') <= max_width:
                line += words.pop(0) + ' '
            if words!=[]:
                hyphenated_word = dic.inserted(words[0]).split('-')
                while hyphenated_word:
                    flag=True
                    if len(hyphenated_word)==2:
                        if len(hyphenated_word[1])<4:
                            flag=False
                    if font.getlength(line + hyphenated_word[0] + '-')<= max_width and flag:
                        line += hyphenated_word.pop(0)
                    else:
                        if not words[0]=="".join(hyphenated_word):
                            line+='-'
                            words[0]="".join(hyphenated_word)
                        break
            lines.append(line)
            if len(lines)==lines_per_page:
                output.append(lines)
                lines=[]
    if len(lines)<lines_per_page:
        while len(lines)<lines_per_page:
            lines.append([])
        output.append(lines)
    return output

# %%
# Настройка шрифта
font_path = "eskal_font4you.ttf"  # Замените на путь к вашему шрифту
font = ImageFont.truetype(font_path, size=400,layout_engine=ImageFont.Layout.BASIC)
width,height=(6992, 9921) # https://pixelcalculator.com/en
draw_lines=True # Рисовать линии строк?

endings=string.whitespace+string.punctuation
os.makedirs('output',exist_ok=True)

# %%
# Текст
text = open('text.txt').read() # Переносы в тексте учитываются
# text=""

x_start, y_start = (width//13,height//45)  # Начальные координаты
padding=x_start
kerning = -width//400  # Отрицательное значение уменьшает расстояние между буквами
line_spacing = 0.97  # Межстрочный интервал
max_offset_step = font.size//100
#max_offset_total = 10
max_angle = 5
max_line_offset = 0
#whitespace_end_only=True
lines_per_page=24

line_color = "grey"  # Цвет линии
line_thickness = height//1000  # Толщина линии

gridsize = (font.size//2, font.size//2)  # Размер сетки для искажения
deviation = font.size//20  # Сила искажения

# Перенос строк
wrapped_text = wrap_text(text, font, width*0.95-x_start,lines_per_page)

for index,page in enumerate(wrapped_text):
    if index%2==0:
        x_start=padding
    else:
        x_start=x_start//10
    print(page)
    x, y = x_start, y_start
    # Создаём холст
    image = Image.new("RGB", (width,height), color='white')
    #image=Image.open('a5_1200.jpg')
    draw = ImageDraw.Draw(image)
    for c,line in enumerate(page):
        if not len(page)-c==1 and draw_lines:
            draw.line([(0, int(y + font.size*0.8)), (width, int(y + font.size*0.8))], fill=line_color, width=line_thickness)

        for i in range(len(line)):
            char = line[i]
            left, top, right, bottom = font.getbbox(char)  # Извлекаем ширину и высоту
            char_width, char_height = (right - left, bottom - top)

            if char == ' ':
                char_width = random.randint(int(char_width*0.7),int(char_width*1.3))

            # Смещение и вращение для каждой буквы
            #offset_x = random.randint(-max_offset_step, max_offset_step)  # Случайное смещение по X
            offset_x = 0  # Случайное смещение по X
            offset_y = random.randint(-max_offset_step, max_offset_step)  # Случайное смещение по Y
            angle = random.randint(-max_angle, max_angle)  # Случайное вращение

            # Создаём изображение для буквы
            char_image = Image.new("RGBA", (int(char_width*1.4), int(char_height*1.4)), (255, 0, 0, 0))
            char_draw = ImageDraw.Draw(char_image)
            char_draw.text((-left+char_width//5, -top+char_height//5), char, font=font, fill="black")

            # Поворот буквы
            char_image = char_image.rotate(angle, resample=Image.BICUBIC, expand=True)

            # Применение искажения сетки
            char_image = warp_image(char_image, gridsize=gridsize, deviation=deviation)

            # Вставляем букву в основное изображение
            image.paste(char_image, (x + offset_x-char_width//5, y + offset_y + top-char_height//5), char_image)

            # Коррекция ширины для конкретных символов
            if char in 'ПбйТГ':
                char_width = int(char_width*0.7)
            if char in 'б':
                char_width = int(char_width*0.7)
            if line[min(i + 1, len(line) - 1)] in "рд":
                char_width = int(char_width*0.5)
            if line[min(i + 1, len(line) - 1)] in "уз":
                char_width = int(char_width*0.7)

            # Смещаем координату X с учётом кернинга
            x += char_width + kerning

        # Переход на новую строку
        x = x_start
        line_height = int(font.size * line_spacing)  # Высота строки с учетом межстрочного интервала
        y += line_height + random.randint(-max_line_offset, max_line_offset)  # Добавляем случайное отклонение
    image.save(os.path.join('output',f'{index}.png'),format='png')
    # Отображаем результат
    #display(image)
# Out:
# [' Стандартизация — деятельность по ', 'установлению норм, правил и характери-', 'стик с целью обеспечения безопасности ', 'продукции, работ и услуг для окружа-', 'ющей среды, жизни, здоровья и имуще-', ' ства; технической и информационной ', 'совместимости, взаимозаменяемости про-', ' дукции; качества продукции, работ и ', ' услуг в соответствии с уровнем науки ', 'и техники; единства измерений; эко-', ' номии ресурсов; безопасности объектов с ', 'учетом риска природных и техногенных ', 'катастроф; обороноспособности и мобили-', 'зационной готовности страны. ', 'Стандартизация направлена на дости-', 'жение оптимальной степени упорядо-', 'чения в определенной области путем ', 'установления положений для всеобщего ', ' и многократного использования. ', ' Объект стандартизации — продукция, ', ' процесс или услуга, подвергшиеся или ', ' подлежащие стандартизации. Область ', 'стандартизации — совокупность взаимо-', ' связанных объектов стандартизации. ']
# [' Основные принципы стандартизации: ', '- добровольность применения стандартов; ', '- консенсус всех заинтересованных ', ' сторон при их разработке; ', '- использование международных стан-', ' дартов как основы национальных; ', ' - соответствие стандартов совре-', ' менным достижениям науки и техно-', ' логий с учетом ограничений; ', ' - возможность объективного контроля ', 'выполнения требований стандартов; ', '- четкость и однозначность изложения ', ' требований. ', ' Уровни и органы стандартизации: ', ' 1. Международный: ', '- ISO (Международная организация по ', 'стандартизации); ', ' - IEC (Международная электротехниче-', 'ская комиссия); ', '- ITU (Международный союз электросвя-', 'зи). ', ' 2. Региональный: ', ' - CEN (Европейский комитет по стан-', ' дартизации); ']
# ['- CENELEC (Европейский комитет по ', 'стандартизации в электротехнике); ', ' - МГС (Международный совет стран ', 'СНГ). ', '3. Национальный: ', '- Госстандарт РФ (Российская Федерация); ', ' - NIST (Американский институт стан-', 'дартов и технологий); ', ' - DIN (Германский институт стандар-', 'тов). ', ' На основании предоставленных изображе-', ' ний, основное можно выделить следу-', 'ющим образом: ', ' Программное обеспечение — совокуп-', ' ность программ, процедур, правил и до-', ' кументации, необходимых для управ-', 'ления вычислительными системами. ', ' Определения варьируются в зависимости ', ' от ГОСТов и стандартов. ', ' Программа — данные или блок ин-', ' струкций, предназначенные для реали-', ' зации алгоритмов и выполнения задач ', 'в рамках системы обработки информа-', ' ции. ']
# ['Программное средство — объект, включа-', 'ющий программы, процедуры, правила и ', ' документацию, необходимые для функ-', 'ционирования системы. ', ' Программный продукт — программное ', ' средство, предназначенное для передачи, ', 'поставки или продажи пользователю. ', ' Программная продукция — про-', 'граммный объект, разработанный для ', ' поставки пользователю. ', ' Если необходимо больше подробностей, я ', ' могу уточнить. ', ' Виды программ: ', '- Компонент — программа с закон-', 'ченной функцией, применяемая самосто-', ' ятельно или в составе комплекса. ', ' - Комплекс — программа из двух и ', 'более компонентов или комплексов, вы-', 'полняющих взаимосвязанные функции, ', 'применяемая самостоятельно или в со-', 'ставе другого комплекса. ', 'Виды программных документов: ', ' - Спецификация — состав программы ', 'и её документации. ']
# ['- Текст программы — записи про-', ' граммы с комментариями. ', '- Описание программы — структура и ', ' функционирование программы. ', '- Программа и методика испытаний — ', 'требования и методы проверки. ', ' - Техническое задание — назначение, ', 'требования и сроки разработки. ', ' - Пояснительная записка — описание ', ' алгоритмов и решений. ', ' - Эксплуатационные документы — ', 'данные для функционирования про-', ' граммы. ', ' Подготовка документации включает ', ' разработку и реализацию плана обозна-', 'чения документов. Проектирование и раз-', ' работка предполагает создание докумен-', ' тации по стандартам, проверку мате-', ' риалов и редактуру. Выпуск включает ', ' издание и управление документацией. ', 'Сопровождение подразумевает внесение из-', ' менений в соответствии с процессами ', 'управления конфигурацией. ', 'Этапы документирования: ']
# ['Получение исходных материалов, разра-', ' ботка и проверка плана документирова-', 'ния. ', ' Разработка документации, ее проверка, ', ' тестирование на практичность, тира-', 'жирование и распространение. ', 'План документирования: ', ' Содержит рабочее наименование, назна-', ' чение, область применения, аудиторию, ', ' обоснование использования, содержание, ', ' объем, номенклатуру поставки, соб-', ' ственника авторских прав. ', 'Определения: ', 'Аудитория — категория пользователей с ', 'одинаковыми требованиями к докумен-', ' тации. ', 'Документатор — сторона, создающая до-', ' кументацию. ', 'Справочный текст — контекстнозави-', 'симая информация для облегчения экс-', 'плуатации. ', 'Диалоговая документация — информа-', 'ция, доступная пользователю, необяза-', ' тельно привязанная к контексту. ']
# [' Справочная система — программа для ', 'просмотра диалоговой документации. ', 'Тестирование на практичность — про-', 'цесс оценки соответствия документации ', 'требованиям. ', 'Жизненный цикл программных средств ', ' описывает развитие системы от за-', ' мысла до списания. Модель жизнен-', ' ного цикла предоставляет струк-', 'турную основу процессов и действий для ', 'организации взаимодействия. ', 'Основные группы процессов жизненного ', ' цикла: ', 'Требования к процессам жизненного ', 'цикла. ', 'Цели и результаты процессов. ', ' Деятельность, необходимая для их вы-', 'полнения. ', 'Организация выбирает процессы для до-', 'стижения целей и результатов стадий ', 'жизненного цикла. ', 'Жизненный цикл описывает развитие ', 'системы, продукта, услуги или проекта ', 'от замысла до списания. Модель жиз-']
# [' ненного цикла служит структурной ', ' основой для процессов и действий, органи-', 'зуемых в стадии, и помогает устанав-', ' ливать связи и понимание между сто-', 'ронами. Процессы разработки программ-', 'ного обеспечения рассматриваются как ', ' часть создания системы. ', ' Модели жизненного цикла программ-', 'ного обеспечения используют три стра-', 'тегии: ', ' Однократный подход — линейная после-', ' довательность этапов разработки. ', ' Инкрементная стратегия — на ', ' старте определяются все требования, а ', ' этапы выполняются через последова-', 'тельные версии с постепенным добавле-', ' нием функций. ', ' Эволюционная стратегия — итераци-', 'онное создание продукта, при котором ', 'требования уточняются в процессе разра-', ' ботки версий. ', ' Каскадная модель обеспечивает полное ', 'документирование этапов, четкое плани-', 'рование сроков и затрат, прозрачность ']
# ['для заказчика. Однако требует утвер-', 'ждения всех требований на первом этапе, ', ' изменения на поздних этапах при-', ' водят к значительным затратам вре-', 'мени и средств. Используется для про-', 'ектов с фиксированными требованиями, ', 'миграции между платформами или ', ' когда тестирование выполняется заказ-', ' чиком или сторонней фирмой. Модель ', ' постепенно уступает место более совре-', 'менным подходам. ', ' Качество программного обеспечения — ', 'это совокупность признаков и характери-', ' стик, определяющих его способность удо-', ' влетворять потребности. Характери-', 'стики качества описывают и оценивают ', ' свойства программной продукции, ко-', ' торые могут быть уточнены через под-', ' характеристики. Метрики качества — ', ' количественные методы для оценки ха-', ' рактеристик программного обеспечения. ', 'Модель оценки зрелости технологиче-', ' ских процессов (CMM) используется ', 'для анализа и повышения качества про-']
# ['цессов разработки программного обеспече-', 'ния. Включает пять уровней зрелости, ', ' определяющих качество создаваемых про-', 'дуктов. Уровни характеризуются сте-', ' пенью формализации, измерения и до-', ' кументирования процессов, широтой ис-', ' пользования стандартов и инстру-', ' ментов автоматизации, а также пол-', 'нотой функций обеспечения качества. ', 'Функциональная пригодность определяет ', 'назначение и необходимые функции про-', ' граммного обеспечения, заданные тех-', ' ническим заданием. Эти атрибуты ', ' конкретизируются в спецификациях ', ' компонентов и оцениваются специали-', 'зированными критериями. ', ' Корректность программы зависит от ', ' точности обработки данных в рамках ', ' требований спецификации. Некоррект-', ' ность определяется вероятностью появ-', 'ления данных, не проверенных при те-', ' стировании. ', ' Надежная программа характеризуется ', 'низкой вероятностью отказа и способно-']
# ['стью быстро реагировать на ошибки, вос-', 'станавливая работоспособность до крити-', 'ческого порога времени. ', 'ГОСТ Р ИСО/МЭК 25010-2015, иден-', ' тичный стандарту ISO/IEC 25010:2011, ', 'описывает модели качества систем и ', 'программных продуктов. Он является пе-', ' ресмотром стандарта ИСО/МЭК -', ' 91261. Стандарт определяет модель ка-', 'чества при использовании, включающую ', ' пять характеристик, связанных с ре-', 'зультатом взаимодействия пользователя ', 'с продуктом, и модель качества про-', ' дукта, состоящую из восьми характери-', 'стик, отражающих статические и дина-', 'мические свойства программного обеспе-', ' чения и вычислительных систем. ', 'В дискретных моделях тестирование про-', 'водится перед эксплуатацией, отказы ', ' фиксируются, ошибки устраняются. ', 'Модель Муса оценивает надежность ПО ', ' после тестирования. ', 'Средняя наработка до отказа определя-', ' ется формулой с учетом времени те-']
# [' стирования, числа отказов и коэффици-', ' ента, отражающего разницу между те-', ' стовым временем и временем эксплуа-', 'тации. Параметр начальной наработки ', ' до отказа вычисляется через число ', ' ошибок, коэффициент их проявления и ', ' среднюю скорость исполнения про-', ' грамм. Надежность ПО в период эксплуа-', ' тации оценивается с использованием со-', 'ответствующих формул. ', 'Тестирование — это выполнение про-', ' грамм для выявления ошибок. Распро-', ' страненные ошибки включают логиче-', ' ские сбои, проблемы с циклами, струк-', 'туры данных, переменные и ввод-вывод. ', 'Тест — это набор данных, условий за-', ' пуска и эталонных результатов. Те-', ' стовое покрытие охватывает линейные ', 'участки программы. Тестирование выяв-', ' ляет только наличие ошибок, но не ', ' может доказать их отсутствие. ', ' Тестирование программ делится на две ', 'основные стратегии: «черный ящик» и ', ' «белый ящик». В тестировании «чер-']
# ['ного ящика» оценивается функциональ-', ' ность программы без учета ее вну-', ' тренней структуры, тестируются ин-', ' терфейсы, ввод данных, выполнение ', 'функций и получение результатов. ', ' Тесты основываются на спецификации, ', 'но внутренние ошибки программы ', 'могут остаться незамеченными. Тести-', ' рование «белого ящика» анализирует ', 'внутреннее поведение программы, кор-', ' ректность построения и взаимодей-', 'ствия элементов, включая ветвления, ', ' циклы и структуры данных. Полное ', ' тестирование маршрутов программы ', ' сложно из-за их огромного количе-', ' ства, но такой подход позволяет вы-', ' явить типовые ошибки, связанные с ло-', 'гикой программы. ', 'Различают детерминированное тестирова-', 'ние, где проверяются все комбинации ', ' входных данных, и стохастическое, ис-', ' пользующее случайные данные. Также ', 'применяются тесты для классов эквива-', ' лентностей, граничных значений, ана-']
# ['лиза причинно-следственных связей и ', 'утверждений в документации. Эта-', 'лонные результаты проверяются через ', ' справочники, ручные вычисления или ', ' надежные программы. ', 'Тестовое покрытие показывает, какие ', ' участки программы проверены те-', ' стами. Производительность программ ', 'тестируется с помощью специализиро-', ' ванных тестов. Отладка, как процесс ', ' поиска и исправления ошибок, базиру-', 'ется на анализе данных и эксперимен-', 'тах. Несмотря на недостатки каждой ', ' стратегии тестирования, их комбиниро-', ' ванное использование позволяет повы-', 'сить качество программного обеспечения. ', 'Потоковый граф отображает управля-', 'ющую структуру программы. Его узлы ', ' соответствуют линейным участкам ', ' программы, а дуги — потокам управ-', ' ления. Предикатные узлы отображают ', 'условия, причем составные условия разби-', ' ваются на несколько узлов. За-', 'мкнутые области графа называются ре-']
# [' гионами, включая окружающую среду ', 'графа. ', 'Цикломатическая сложность — мет-', ' рика, оценивающая логическую слож-', 'ность программы. Она определяет коли-', 'чество независимых путей, необходимых ', 'для выполнения всех операторов и ', ' условий программы. Независимые пути ', 'начинаются в начальном узле графа и ', 'содержат новые дуги. ', ' Цикломатическая сложность равна ', 'числу регионов графа, вычисляется по ', 'формуле V(G)=E-N+2 (где E — количе-', 'ство дуг, N — количество узлов) или ', 'по числу предикатных узлов V(G) = p+1.', 'p+1. Она задает априорную оценку ко-', 'личества независимых путей, необхо-', 'димых для тестирования. ', 'Способ тестирования базового пути позво-', 'ляет оценить сложность программы ', ' через расчет цикломатической слож-', ' ности и определить минимальное ко-', ' личество тестов, необходимое для про-', ' верки всех независимых путей. Каждый ']
# ['независимый путь тестируется от-', 'дельным тестовым вариантом, который ', ' формируется так, чтобы пройти кон-', ' кретный маршрут. ', ' Шаги тестирования: ', '1. Формирование потокового графа на ', ' основе программы. ', ' 2. Вычисление цикломатической слож-', 'ности. ', ' 3. Определение базового множества неза-', ' висимых путей. ', '4. Подготовка тестовых вариантов для ', 'выполнения каждого пути. ', 'Результаты тестов сравниваются с ожи-', 'даемыми, что гарантирует выполнение ', 'всех операторов программы хотя бы один ', ' раз. Независимые пути, которые не ', ' могут быть проверены изолированно, ', 'тестируются как часть других те-', 'стовых вариантов. ', 'Функциональное тестирование с использо-', ' ванием разбиения по эквивалентности ', 'и анализа граничных значений предпо-', 'лагает разделение входных данных на ']
# [' классы эквивалентности — допу-', 'стимые и недопустимые. Условия ввода ', ' могут задаваться фиксированным зна-', 'чением, диапазоном, множеством зна-', 'чений или булевыми значениями. На-', 'пример, для диапазона допустимыми ', 'будут значения внутри него, а недопу-', ' стимыми — меньше или больше ', ' границ диапазона. ', ' Для программы бинарного поиска ана-', ' лизируются предусловия (упорядочен-', 'ность массива и наличие хотя бы од-', 'ного элемента) и постусловия (правиль-', ' ность результата поиска). Дополни-', 'тельно учитываются специальные слу-', ' чаи, такие как массив из одного эле-', 'мента, четного или нечетного количе-', 'ства элементов. Граничные значения ', 'анализируются на примерах работы с ', ' первым, последним и промежуточным ', ' элементами массива, что позволяет ', ' проверять корректность поведения про-', 'граммы в различных ситуациях. ', 'Функциональное тестирование с использо-']
# [' ванием диаграмм причин-следствий ', 'включает перечисление причин (условий ', 'ввода) и следствий (действий или условий ', 'вывода) с присвоением идентификаторов. ', ' На основе этого строится граф при-', 'чинноследственных связей, который преоб-', 'разуется в таблицу решений. Из ', 'столбцов таблицы формируются те-', ' стовые варианты для проверки взаимо-', 'связей между условиями ввода и действи-', 'ями программы. ', ' Требования к качеству программного ', 'продукта включают понятность, пол-', ' ноту, непротиворечивость, проверяемость ', ' и простоту обозрения. Требования к ', 'описанию продукта должны быть чет-', 'кими, полными, корректными и про-', ' стыми для изучения. Описание должно ', 'содержать обозначение продукта, постав-', 'щика, рабочую задачу, систему, интер-', 'фейсы, объекты поставки, инструкции ', ' по установке, поддержке и сопровожде-', ' нию. Основные критерии качества: ', 'функциональность, надежность, эффек-']
# [' тивность, практичность, сопровождае-', ' мость и мобильность. ', ' В двухзвенных моделях «клиент-сервер» ', ' доступ к базам данных может осуще-', 'ствляться через ODBC-драйверы для про-', ' стых систем. В более сложных много-', 'звенных системах используется SQL-', ' шлюз, который унифицирует запросы ', 'к разнородным СУБД, выполняет их раз-', ' бор, оптимизацию и преобразование в ', 'нужный SQL-диалект. ', 'Приложение в архитектуре «клиентсер-', ' вер» состоит из клиентской части, ', 'обеспечивающей обработку данных и взаи-', ' модействие с пользователем, и серверной ', 'части, хранящей данные, обрабатыва-', 'ющей запросы и отправляющей резуль-', ' таты клиенту. Клиентские узлы ', 'подключены к серверу БД через сеть. ', ' Приложения разрабатываются на ', 'языках высокого уровня с включением -', ' SQLвыражений для работы с данными. ', 'Сервер выполняет запросы и возвращает ', 'результаты клиенту для дальнейшей об-']
# [' работки, включая изменение записей. ', 'Основные требования к распределенной об-', 'работке данных включают: ', 'Прозрачность расположения данных — ', ' данные должны восприниматься пользо-', 'вателем как локальные. ', 'Прозрачность относительно сети — оди-', ' наковая эффективность работы незави-', ' симо от сети, пользователь не должен ', ' знать, через какую сеть происходит до-', 'ступ. ', ' Гетерогенность системы — независи-', ' мость от архитектуры и СУБД на ', ' разных вычислительных машинах. ', 'Поддержка распределенных запросов — воз-', 'можность объединять данные из разных ', 'баз, даже если они находятся в разных ', 'системах. ', ' Поддержка распределенных изменений — ', 'возможность изменять данные в разных ', ' базах, независимо от их местоположе-', 'ния. ', 'Поддержка распределенных транзакций — ', 'обеспечение целостности базы данных ']
# ['при отказах, выполнение транзакций ', 'как неделимых операций. ', ' Безопасность — защита базы данных ', ' от несанкционированного доступа. ', 'Универсальность доступа — единый ', 'метод и интерфейс доступа ко всем дан-', 'ным, независимо от их платформ и ', ' требований. ', 'Режимы работы с базами данных за-', ' висят от технологий: первая предпола-', ' гает централизованную базу данных, ', ' вторая — распределенные базы данных ', 'с возможностью как локальной, так и ', 'распределенной обработки. ', 'Системы распределенных баз данных поз-', 'воляют обрабатывать запросы, используя ', ' данные, размещенные на разных ЭВМ ', 'сети, обеспечивая пользователю доступ к ', 'данным так, будто они локальны. Про-', 'граммы обработки данных разделяют ', ' функции между центральным про-', 'цессом СУБД и клиентскими процедурами ', 'для эффективного использования ресурсов. ', ' Типовое приложение обработки данных ']
# [' включает: ', 'Ввод и отображение данных (Presentation ', 'logic). ', 'Функциональную обработку, реализу-', 'ющую бизнес-правила (Business logic). ', 'Манипулирование данными БД сред-', ' ствами SQL (Database logic). ', 'Управление данными и ресурсами сред-', ' ствами СУБД (Common Database Logic). ', 'Управление процессами обработки и их ', ' синхронизацию (Resource Logic). ', ' Базовые архитектуры распределенной об-', 'работки данных: ', 'Файл-сервер: СУБД и управление данными ', ' находятся на клиентской машине, а ', ' сервер предоставляет удаленный доступ ', 'к файлам. ', 'Выделенный сервер базы данных: СУБД и ', 'данные находятся на сервере. Запросы об-', 'рабатываются на сервере, а клиент полу-', ' чает запрашиваемые записи. ', 'Активный сервер баз данных: Бизнесло-', ' гика и контроль изменений базы ', ' данных выполняются на стороне сер-']
# ['вера, обеспечивая непротиворечивость опера-', 'ций. ', 'Сервер приложений: Трехзвенная архитек-', 'тура, где сервер приложений обрабатывает ', ' данные и бизнес-логику, а сервер базы ', ' данных отвечает за хранение данных. ', ' Это снижает требования к ресурсам ', ' клиента. ', ' Сертификация — это процедура, подтвер-', 'ждающая соответствие продукта, про-', ' цесса или услуги установленным тре-', 'бованиям. В случае программного обеспе-', 'чения сертификация учитывает высокие ', ' требования к надежности, обработке ', ' больших объемов данных, постоянным ', ' доработкам, защите информации и спе-', 'цифичности программ, что снижает их ', 'тиражируемость. ', 'Система менеджмента качества управ-', 'ляет процессами и ресурсами для дости-', 'жения целей организации, обеспечения ', 'ценности для заинтересованных сторон ', 'и оптимизации ресурсов. Она позволяет ', ' идентифицировать действия по устра-']
# ['нению преднамеренных или непреднаме-', ' ренных последствий в предоставлении ', ' продукции и услуг. ', 'Принципы менеджмента качества вклю-', ' чают ориентацию на потребителей, ', 'лидерство, вовлечение персонала, про-', 'цессный подход, постоянное улучшение, ', 'принятие решений на основе данных и ', 'управление взаимоотношениями с заин-', ' тересованными сторонами. ', ' ГОСТ Р ИСО 9001-2015 направлен на ', ' внедрение процессного подхода для повы-', ' шения эффективности системы мене-', ' джмента качества и удовлетворения по-', ' требностей потребителей. Применение ', 'процессного подхода позволяет выполнять ', 'требования, добавлять ценность через про-', 'цессы, обеспечивать их эффективное функ-', ' ционирование и улучшать их на ', 'основе анализа данных. ', 'Форматы представления данных использу-', ' ются для стандартизации обмена ин-', ' формацией. Примером коммуника-', 'тивных форматов является MARC -']
# ['(MachineReadable Catalogue), созданный ', 'Библиотекой Конгресса США в 1965–1966 ', ' гг., который используется для обмена ', 'библиографическими данными. ', ' ГОСТ 7.14-98 (ИСО 2709-96) определяет ', ' структуру формата для представления ', ' и обмена информацией. Он предна-', ' значен для описания любого матери-', ' ала, поддающегося библиографическому ', 'описанию, и обеспечивает коммуникацию ', ' между системами обработки данных, а ', 'не внутри них. Стандарт отражает ', 'международные требования ISO 2709-96 с ', ' учетом потребностей экономики. ', 'Библиографическая запись в формате ISO-', '2709 состоит из полей, описывающих ', ' одну или несколько библиографических ', 'единиц. Она имеет три блока: заголо-', 'вок, справочник и область элементов ', 'данных. Структура записи «самоопреде-', 'ленная», что позволяет каждому экзем-', ' пляру иметь уникальный состав полей ', ' и способ представления данных. Спра-', 'вочник переменной длины определяет ']
# [' размещение полей данных, а струк-', 'тура справочника и элементов данных ', ' задается заголовком. ', ' XML (Extensible Markup Language) — ', 'язык разметки для описания данных в ', ' виде документов, называемых XMLдоку-', ' ментами. ', ' Требования к «хорошо оформленным» -', ' XMLдокументам: ', 'Все элементы должны иметь закрыва-', ' ющий тег. ', ' В тегах учитывается регистр. ', 'Элементы должны быть правильно вло-', ' жены. ', 'Документ должен иметь единственный ', 'корневой элемент. ', ' Значения атрибутов заключаются в ', 'кавычки. ', 'Пробелы считаются значимыми. ', 'Зарезервированные символы используются ', 'только как элементы синтаксиса (<, ', '>, &, “, ‘). ', ' XML-схема используется для опреде-', ' ления структуры и содержания XMLдо-']
# ['кументов, задавая допустимые эле-', ' менты, атрибуты и их взаимосвязи. ', 'Открытые системы обладают следую-', 'щими свойствами: ', 'Взаимодействие — способность работать с ', 'другими системами на разных платфор-', 'мах. ', 'Стандартизуемость — разработка на ', ' основе международных стандартов и ', 'функциональных профилей в области ', 'ИТ. ', 'Расширяемость — возможность добав-', 'ления новых функций или изменения ', ' существующих без влияния на ', ' остальные части системы. ', 'Мобильность — перенос программ и ', 'данных при смене платформ без необхо-', 'димости переподготовки пользователей. ', 'Дружественность к пользователю — уни-', 'фицированные интерфейсы, обеспечива-', ' ющие работу без специальной подго-', ' товки. ', 'Открытая система — это система, ком-', 'поненты которой взаимодействуют через ']
# ['стандартные интерфейсы и обеспечивают ', ' интеграцию разнородных компьютеров, ', 'независимо от их расположения, операци-', ' онных систем, представления инфор-', 'мации и производителя. Она реализует ', 'международные стандартные протоколы, ', ' обеспечивая интероперабельность, мобиль-', ' ность приложений, данных и персо-', 'нала. ', ' Эталонная модель среды взаимодействия ', 'открытых систем (OSE) описывает логи-', ' ческие объекты, такие как прикладное ', 'ПО, платформы и внешняя функцио-', ' нальная среда, а также интерфейсы ', 'прикладной системы и внешней среды. ', 'Эталонная модель OSI (ГОСТ Р ', 'ИСО/МЭК 7498-1) определяет уровни взаи-', 'модействия систем. Протоколы описы-', ' вают правила взаимодействия объектов ', 'одноименных уровней, а интерфейсы за-', 'дают правила взаимодействия между объ-', ' ектами разных уровней. ', 'Открытая система — это система, ко-', 'торая взаимодействует через стан-']
# [' дартные интерфейсы и обеспечивает ин-', ' теграцию разнородных компьютеров, не-', 'зависимо от их расположения, производи-', ' теля, представления информации и опе-', 'рационной системы. Она реализует меж-', 'дународные стандарты, обеспечивая инте-', ' роперабельность и мобильность приложе-', ' ний, данных и пользователей. ', 'Профиль открытой системы — это сово-', 'купность стандартов с четко определен-', 'ными возможностями, предназначенная ', ' для реализации функций в кон-', 'кретной среде. Профиль формируется ис-', 'ходя из функциональных характеристик ', 'объекта или процесса. ', ' Примером является GOSIP (Government ', 'Open System Interconnection Profile), в ', 'России утвержден Государственный про-', 'филь взаимосвязи открытых систем ', ' (ГОСТ Р 50.1.22-2000). ', [], [], [], []]

# %%
def combine_photos(photo_paths, output_path, line_color="black", line_thickness=2):
    """
    Совмещает фотографии по парам в альбомной ориентации с вертикальной линией на границе.

    :param photo_paths: Список путей к портретным фотографиям.
    :param output_path: Путь для сохранения объединенных фотографий.
    :param line_color: Цвет разделительной линии (по умолчанию: черный).
    :param line_thickness: Толщина разделительной линии (по умолчанию: 2 пикселя).
    """

    photo_paths.extend([None for _ in range(4-len(photo_paths)%4)])
    paired_photos=[]
    for i in range(0,len(photo_paths),4):
        paired_photos.append((photo_paths[i],photo_paths[i+2]))
        paired_photos.append((photo_paths[i+3],photo_paths[i+1]))

    for idx, (photo1_path, photo2_path) in enumerate(paired_photos):
        if not photo1_path:
            photo1 = Image.open(f'{photo_folder}/blank.png')
        else:
            photo1 = Image.open(photo1_path)

        if not photo2_path:
            photo2 = Image.open(f'{photo_folder}/blank.png')
        else:
            photo2 = Image.open(photo2_path)

        # Проверяем ориентацию
        if photo1.size[0] > photo1.size[1] or photo2.size[0] > photo2.size[1]:
            raise ValueError("Фотографии должны быть в портретной ориентации.")

        # Вычисляем размеры нового изображения
        width = photo1.size[0] + photo2.size[0] + line_thickness
        height = max(photo1.size[1], photo2.size[1])

        # Создаем новое изображение
        combined_image = Image.new("RGB", (width, height), "white")
    
        # Вставляем фотографии
        combined_image.paste(photo1, (0, 0))
        combined_image.paste(photo2, (photo1.size[0] + line_thickness, 0))

        # Рисуем разделительную линию
        draw = ImageDraw.Draw(combined_image)
        line_x = photo1.size[0]
        draw.rectangle([(line_x, 0), (line_x + line_thickness - 1, height)], fill=line_color)
        
        # Сохраняем результат
        output_file = os.path.join(output_path, f"combined_{idx + 1}.png")
        combined_image.save(output_file)
        #display(combined_image)

# Пример использования
photo_folder = "output"  # Папка с фотографиями
output_folder = "output_merged"  # Папка для сохранения результатов
os.makedirs(output_folder, exist_ok=True)
files=os.listdir(photo_folder)
files.remove('blank.png')
files.sort(key=lambda x: int(x.removesuffix('.png')))
# Список фотографий
photos = [os.path.join(photo_folder, f) for f in files]

combine_photos(photos, output_folder)

# %%
# Настройка шрифта
font_path = "eskal_font4you.ttf"  # Замените на путь к вашему шрифту
font = ImageFont.truetype(font_path, size=50)

# Алфавит (можете изменить набор символов, если необходимо)
characters = 'абвгдеёжзиклмнопрстуфхцчшщъэьюя'.upper()+'абвгдеёжзиклмнопрстуфхцчшщъэьюя'

# Генерация и вывод изображений для каждого символа
for char in characters:
    # Определяем размеры символа
    left, top, right, bottom = font.getbbox(char)  # Извлекаем ширину и высоту
    char_width, char_height=(right-left,bottom-top)
    # Создаём изображение, равное размеру символа
    char_image = Image.new("RGBA", (char_width, char_height), (255, 255, 255, 0))
    warped_image = warp_image(char_image, gridsize=(30, 30), deviation=10)
    char_draw = ImageDraw.Draw(warped_image)

    # Рисуем символ
    char_draw.text((-left, -top), char, font=font, fill="black")

    # Выводим символ через display
    print(f"Символ: '{char if char.strip() else 'space'}'",left, top, right, bottom)
    display(warped_image)
